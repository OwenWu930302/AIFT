# %%
import yfinance as yf
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import statsmodels.api as sm
import inspect
import os
from datetime import datetime
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Create a directory for saving results
if not os.path.exists("results"):
    os.makedirs("results")

# Constants
INITIAL_CAPITAL = 10000
# Using 5 diverse stocks from different sectors
TICKERS = ['AAPL', 'MSFT', 'JPM', 'PFE', 'XOM']
START_DATE = "2015-04-15"
END_DATE = "2025-04-15"

# 1. Fetch data for all five stocks
print("Fetching stock data...")
stock_data = {}
for ticker in TICKERS:
    stock_data[ticker] = yf.download(ticker, start=START_DATE, end=END_DATE)
    print(f"Downloaded data for {ticker}: {len(stock_data[ticker])} trading days")

# 2. LSTM Model for price prediction
class LSTMModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=32, num_layers=1, batch_first=True)
        self.fc = nn.Linear(32, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])

def create_dataset(data, seq_len=30):
    """Creates sequence data for LSTM"""
    X, y = [], []
    for i in range(len(data)-seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len])
    return np.array(X), np.array(y)

def train_lstm_model(data_scaled, seq_len=30, epochs=20):
    """Train LSTM model on scaled data"""
    X, y = create_dataset(data_scaled, seq_len)
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.float32)

    model = LSTMModel()
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    for epoch in range(epochs):
        output = model(X)
        loss = criterion(output, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if epoch % 5 == 0:
            print(f"Epoch {epoch}, Loss: {loss.item():.4f}")

    return model, X, y

# 3. Define investment strategies
def lump_sum_strategy(prices, initial_capital=INITIAL_CAPITAL):
    """Buy and hold strategy - invest all at the beginning"""
    if len(prices) == 0:
        return [initial_capital]

    shares = initial_capital / prices[0]
    portfolio_values = [shares * price for price in prices]

    # Ensure we have a proper list of values
    if not portfolio_values:
        return [initial_capital] * len(prices)

    return portfolio_values

def dca_strategy(prices, initial_capital=INITIAL_CAPITAL, intervals=12):
    """Dollar Cost Averaging - invest equal amounts at regular intervals"""
    if len(prices) == 0:
        return [initial_capital]

    period_investment = initial_capital / intervals
    shares = 0
    cash = initial_capital
    portfolio_values = []

    interval_days = max(1, len(prices) // intervals)

    for i, price in enumerate(prices):
        if i % interval_days == 0 and cash > 0:
            investment = min(period_investment, cash)
            shares += investment / price
            cash -= investment

        portfolio_value = shares * price + cash
        portfolio_values.append(portfolio_value)

    # Ensure we have a proper list of values
    if not portfolio_values:
        return [initial_capital] * len(prices)

    return portfolio_values

def lstm_strategy(model, scaled_data, scaler, initial_capital=INITIAL_CAPITAL, seq_len=30):
    """Trading strategy based on LSTM predictions"""
    try:
        price_data = scaler.inverse_transform(scaled_data)[:, 0]

        # Make predictions
        with torch.no_grad():
            X, _ = create_dataset(scaled_data, seq_len)
            X_tensor = torch.tensor(X, dtype=torch.float32)
            predicted = model(X_tensor).numpy()

        pred_price = scaler.inverse_transform(predicted)[:, 0]

        # Trading logic - buy when predicted price rise, sell when predicted price fall
        position = 0
        cash = initial_capital
        portfolio = [initial_capital]  # Start with initial capital

        for i in range(1, len(pred_price)):
            current_price = price_data[i+seq_len-1]  # Current actual price

            if pred_price[i] > pred_price[i-1] and position == 0:  # Predicted price rise
                position = cash / current_price
                cash = 0
            elif pred_price[i] < pred_price[i-1] and position > 0:  # Predicted price fall
                cash = position * current_price
                position = 0

            portfolio_value = cash + position * current_price
            portfolio.append(portfolio_value)

        # Ensure we have a proper list of values
        if not portfolio:
            return [initial_capital] * len(price_data)

        return portfolio
    except Exception as e:
        print(f"Error in LSTM strategy: {str(e)}")
        # Return a default portfolio of initial capital
        return [initial_capital] * len(scaled_data)

def moving_average_strategy(prices, short_window=20, long_window=50, initial_capital=INITIAL_CAPITAL):
    """Moving Average crossover strategy"""
    if len(prices) <= long_window:
        return [initial_capital] * len(prices)

    try:
        # Calculate moving averages
        df = pd.DataFrame(index=range(len(prices)))
        df['price'] = prices
        df['short_ma'] = df['price'].rolling(window=short_window).mean()
        df['long_ma'] = df['price'].rolling(window=long_window).mean()

        # Generate signals - using loc instead of chained assignment
        df['signal'] = 0.0
        df.loc[long_window:, 'signal'] = np.where(df['short_ma'][long_window:] > df['long_ma'][long_window:], 1.0, 0.0)
        df['position'] = df['signal'].diff()

        # Initialize portfolio metrics
        cash = initial_capital
        shares = 0
        portfolio_values = [initial_capital] * long_window  # Initialize with initial capital

        # Backtest the strategy
        for i in range(long_window, len(df)):
            price = df['price'][i]

            # Buy signal
            if df['position'][i] == 1.0:
                shares = cash / price
                cash = 0

            # Sell signal
            elif df['position'][i] == -1.0:
                cash = shares * price
                shares = 0

            portfolio_value = cash + shares * price
            portfolio_values.append(portfolio_value)

        # Ensure we have a proper list of values
        if not portfolio_values:
            return [initial_capital] * len(prices)

        return portfolio_values
    except Exception as e:
        print(f"Error in Moving Average strategy: {str(e)}")
        return [initial_capital] * len(prices)

# Enhanced moving average strategy with RSI for confirmation
def enhanced_ma_rsi_strategy(prices, short_window=20, long_window=50, rsi_period=14,
                            rsi_overbought=70, rsi_oversold=30, initial_capital=INITIAL_CAPITAL):
    """Enhanced Moving Average strategy with RSI confirmation"""
    if len(prices) <= max(long_window, rsi_period):
        return [initial_capital] * len(prices)

    try:
        # Calculate moving averages and RSI
        df = pd.DataFrame(index=range(len(prices)))
        df['price'] = prices
        df['short_ma'] = df['price'].rolling(window=short_window).mean()
        df['long_ma'] = df['price'].rolling(window=long_window).mean()

        # Calculate RSI
        delta = df['price'].diff()
        gain = delta.where(delta > 0, 0).fillna(0)
        loss = -delta.where(delta < 0, 0).fillna(0)

        avg_gain = gain.rolling(window=rsi_period).mean()
        avg_loss = loss.rolling(window=rsi_period).mean()

        # Handle division by zero
        avg_loss = avg_loss.replace(0, 0.00001)

        rs = avg_gain / avg_loss
        df['rsi'] = 100 - (100 / (1 + rs))

        # Generate signals
        df['ma_signal'] = 0.0
        df.loc[long_window:, 'ma_signal'] = np.where(df['short_ma'][long_window:] > df['long_ma'][long_window:], 1.0, 0.0)

        # Only take buy signals when RSI is not overbought, and sell signals when RSI is not oversold
        df['signal'] = 0.0

        # Use iloc instead of boolean indexing to avoid SettingWithCopyWarning
        for i in range(max(long_window, rsi_period), len(df)):
            if df.iloc[i]['ma_signal'] == 1.0 and df.iloc[i]['rsi'] < rsi_overbought:
                df.loc[i, 'signal'] = 1.0
            elif df.iloc[i]['ma_signal'] == 0.0 and df.iloc[i]['rsi'] > rsi_oversold:
                df.loc[i, 'signal'] = 0.0

        df['position'] = df['signal'].diff()

        # Initialize portfolio metrics
        cash = initial_capital
        shares = 0
        min_idx = max(long_window, rsi_period)
        portfolio_values = [initial_capital] * min_idx  # Initialize with initial capital

        # Backtest the strategy
        for i in range(min_idx, len(df)):
            price = df['price'][i]

            # Buy signal
            if df['position'][i] == 1.0:
                shares = cash / price
                cash = 0

            # Sell signal
            elif df['position'][i] == -1.0:
                cash = shares * price
                shares = 0

            portfolio_value = cash + shares * price
            portfolio_values.append(portfolio_value)

        # Ensure we have a proper list of values
        if not portfolio_values:
            return [initial_capital] * len(prices)

        return portfolio_values
    except Exception as e:
        print(f"Error in Enhanced MA-RSI strategy: {str(e)}")
        return [initial_capital] * len(prices)

# Helper function to filter parameters for a function
def filter_params_for_function(func, params):
    """
    Filter parameters to only include those accepted by the function
    """
    sig = inspect.signature(func)
    valid_params = {}
    for name, param in sig.parameters.items():
        if name in params:
            valid_params[name] = params[name]
    return valid_params

# 4. Temporal Validation Implementation - Fixed to filter function parameters
def temporal_validation(prices, strategy_func, train_years, test_year, trading_days_per_year=252, **strategy_params):
    """
    Implement temporal validation for strategy testing
    prices: full price history
    train_years: number of years to use for training
    test_year: number of years to use for testing
    """
    try:
        # Calculate cutoff points
        train_days = int(train_years * trading_days_per_year)
        test_days = int(test_year * trading_days_per_year)

        if len(prices) < train_days + test_days:
            return None  # Not enough data

        # Split data
        train_prices = prices[:train_days]
        test_prices = prices[train_days:train_days+test_days]

        if strategy_func == lstm_strategy:
            # Special handling for LSTM strategy which requires preprocessing
            scaler = MinMaxScaler()
            train_scaled = scaler.fit_transform(train_prices.reshape(-1, 1))

            # Train LSTM model on training data
            seq_len = strategy_params.get('seq_len', 30)
            model, _, _ = train_lstm_model(train_scaled, seq_len)

            # Prepare full dataset for prediction (need to include training for context)
            full_scaled = scaler.transform(prices[:train_days+test_days].reshape(-1, 1))

            # Get portfolio values from LSTM strategy
            portfolio_values = lstm_strategy(model, full_scaled, scaler, INITIAL_CAPITAL, seq_len)
            # Only keep the test period values
            test_portfolio_values = portfolio_values[-test_days:]
        else:
            # For standard strategies - Filter parameters to only include those accepted by the function
            filtered_params = filter_params_for_function(strategy_func, strategy_params)
            test_portfolio_values = strategy_func(test_prices, **filtered_params)

        # Calculate annual return
        if len(test_portfolio_values) > 0:
            annual_return = calculate_annual_return(test_portfolio_values[-1], INITIAL_CAPITAL, test_year)
        else:
            annual_return = 0

        return {
            'portfolio_values': test_portfolio_values,
            'annual_return': annual_return
        }
    except Exception as e:
        print(f"Error in temporal validation: {str(e)}")
        return {
            'portfolio_values': [INITIAL_CAPITAL] * int(test_year * trading_days_per_year),
            'annual_return': 0
        }


#####第二題######


# 5. Pairs Trading Implementation
def calculate_hedge_ratio(price1, price2):
    """Calculate hedge ratio between two stock price series"""
    try:
        X = sm.add_constant(price1)
        model = sm.OLS(price2, X).fit()
        return model.params[1]
    except Exception as e:
        print(f"Error calculating hedge ratio: {str(e)}")
        # Return a default ratio of 1.0 as fallback
        return 1.0

def pairs_trading_strategy(stock1_prices, stock2_prices, z_threshold=2.0, initial_capital=INITIAL_CAPITAL):
    """Implement pairs trading strategy"""
    try:
        # Ensure same length
        min_len = min(len(stock1_prices), len(stock2_prices))
        if min_len == 0:
            return [initial_capital]

        stock1_prices = stock1_prices[:min_len]
        stock2_prices = stock2_prices[:min_len]

        # Calculate hedge ratio
        hedge_ratio = calculate_hedge_ratio(stock1_prices, stock2_prices)

        # Calculate spread
        spread = stock2_prices - hedge_ratio * stock1_prices

        # Calculate z-score
        spread_mean = np.mean(spread)
        spread_std = np.std(spread)

        # Handle zero standard deviation
        if spread_std == 0:
            spread_std = 0.00001

        z_score = (spread - spread_mean) / spread_std

        # Initialize portfolio
        cash = initial_capital
        stock1_shares = 0
        stock2_shares = 0
        portfolio_values = [initial_capital]

        # Backtest the strategy
        for i in range(1, len(z_score)):
            # Trading logic
            if z_score[i-1] > z_threshold and z_score[i] <= z_threshold:
                # Close short position in stock1 and long position in stock2
                if stock1_shares < 0:
                    cash += stock1_shares * stock1_prices[i]  # Buy back stock1 (close short)
                    cash += stock2_shares * stock2_prices[i]  # Sell stock2 (close long)
                    stock1_shares = 0
                    stock2_shares = 0

            elif z_score[i-1] < -z_threshold and z_score[i] >= -z_threshold:
                # Close long position in stock1 and short position in stock2
                if stock1_shares > 0:
                    cash += stock1_shares * stock1_prices[i]  # Sell stock1 (close long)
                    cash += stock2_shares * stock2_prices[i]  # Buy back stock2 (close short)
                    stock1_shares = 0
                    stock2_shares = 0

            elif z_score[i] > z_threshold and stock1_shares == 0:
                # Open short position in stock1 and long position in stock2
                trade_amount = cash / 2
                stock1_shares = -trade_amount / stock1_prices[i]  # Short stock1
                stock2_shares = trade_amount / stock2_prices[i]   # Long stock2
                cash += trade_amount  # Cash from shorting stock1
                cash -= trade_amount  # Cash used to buy stock2

            elif z_score[i] < -z_threshold and stock1_shares == 0:
                # Open long position in stock1 and short position in stock2
                trade_amount = cash / 2
                stock1_shares = trade_amount / stock1_prices[i]   # Long stock1
                stock2_shares = -trade_amount / stock2_prices[i]  # Short stock2
                cash -= trade_amount  # Cash used to buy stock1
                cash += trade_amount  # Cash from shorting stock2

            # Calculate current portfolio value
            current_value = cash + stock1_shares * stock1_prices[i] + stock2_shares * stock2_prices[i]
            portfolio_values.append(current_value)

        # Ensure we have a proper list of values
        if not portfolio_values:
            return [initial_capital] * min_len

        return portfolio_values
    except Exception as e:
        print(f"Error in pairs trading strategy: {str(e)}")
        return [initial_capital] * min(len(stock1_prices), len(stock2_prices))

# Function to implement temporal validation for pairs trading
def pairs_trading_temporal_validation(stock1_prices, stock2_prices, train_years, trading_days_per_year=252,
                                      z_threshold=2.0, initial_capital=INITIAL_CAPITAL):
    try:
        # Calculate training period in days
        train_days = int(train_years * trading_days_per_year)

        # Ensure there's enough data
        min_len = min(len(stock1_prices), len(stock2_prices))
        if min_len <= train_days:
            return None  # Not enough data

        # Split data into training and testing
        stock1_train = stock1_prices[:train_days]
        stock1_test = stock1_prices[train_days:]

        stock2_train = stock2_prices[:train_days]
        stock2_test = stock2_prices[train_days:]

        # Calculate hedge ratio on training data
        X = sm.add_constant(stock1_train)
        model = sm.OLS(stock2_train, X).fit()
        hedge_ratio = model.params[1]

        # Calculate spread on training data
        train_spread = stock2_train - hedge_ratio * stock1_train
        spread_mean = np.mean(train_spread)
        spread_std = np.std(train_spread)

        # Handle zero standard deviation
        if spread_std == 0:
            spread_std = 0.00001

        # Calculate the spread on test data using parameters from training
        test_spread = stock2_test - hedge_ratio * stock1_test
        z_score = (test_spread - spread_mean) / spread_std

        # Initialize portfolio
        cash = initial_capital
        stock1_shares = 0
        stock2_shares = 0
        portfolio_values = [initial_capital]

        # Backtest on test data
        for i in range(1, len(z_score)):
            # Trading logic
            if z_score[i-1] > z_threshold and z_score[i] <= z_threshold:
                # Close short position
                if stock1_shares < 0:
                    cash += stock1_shares * stock1_test[i]
                    cash += stock2_shares * stock2_test[i]
                    stock1_shares = 0
                    stock2_shares = 0

            elif z_score[i-1] < -z_threshold and z_score[i] >= -z_threshold:
                # Close long position
                if stock1_shares > 0:
                    cash += stock1_shares * stock1_test[i]
                    cash += stock2_shares * stock2_test[i]
                    stock1_shares = 0
                    stock2_shares = 0

            elif z_score[i] > z_threshold and stock1_shares == 0:
                # Open short position in stock1, long in stock2
                trade_amount = cash / 2
                stock1_shares = -trade_amount / stock1_test[i]
                stock2_shares = trade_amount / stock2_test[i]
                cash += trade_amount
                cash -= trade_amount

            elif z_score[i] < -z_threshold and stock1_shares == 0:
                # Open long position in stock1, short in stock2
                trade_amount = cash / 2
                stock1_shares = trade_amount / stock1_test[i]
                stock2_shares = -trade_amount / stock2_test[i]
                cash -= trade_amount
                cash += trade_amount

            # Calculate portfolio value
            portfolio_value = cash + stock1_shares * stock1_test[i] + stock2_shares * stock2_test[i]
            portfolio_values.append(portfolio_value)

        # Calculate test period in years
        test_years = len(stock1_test) / trading_days_per_year

        # Calculate annual return
        annual_return = calculate_annual_return(portfolio_values[-1], initial_capital, test_years)

        return {
            'portfolio_values': portfolio_values,
            'annual_return': annual_return,
            'test_years': test_years
        }
    except Exception as e:
        print(f"Error in pairs trading temporal validation: {str(e)}")
        test_days = len(stock1_prices) - train_days if len(stock1_prices) > train_days else 1
        test_years = test_days / trading_days_per_year
        return {
            'portfolio_values': [initial_capital] * test_days,
            'annual_return': 0,
            'test_years': test_years
        }

# Helper function to calculate annualized returns - FIXED to handle array inputs properly
def calculate_annual_return(final_value, initial_value, years):
    """Calculate annualized return, handling both scalar and array inputs"""
    try:
        # If final_value is an array, take the first (or last) element
        if isinstance(final_value, (list, np.ndarray)):
            if len(final_value) > 0:
                final_value = float(final_value[-1])  # Take the last value if it's a list/array
            else:
                return 0  # Empty array, return 0

        # If initial_value is an array, take the first (or first) element
        if isinstance(initial_value, (list, np.ndarray)):
            if len(initial_value) > 0:
                initial_value = float(initial_value[0])  # Take the first value if it's a list/array
            else:
                return 0  # Empty array, return 0

        # Convert to float to ensure scalar calculation
        final_value = float(final_value)
        initial_value = float(initial_value)
        years = float(years)

        # Handle edge cases
        if years <= 0 or initial_value <= 0 or final_value <= 0:
            return 0

        # Calculate annual return
        return (final_value / initial_value) ** (1 / years) - 1
    except Exception as e:
        print(f"Error calculating annual return: {str(e)}")
        return 0

# FIXED: Function to calculate risk metrics with improved error handling
def calculate_risk_metrics(portfolio_values, risk_free_rate=0.02):
    """
    Calculate risk-adjusted performance metrics

    Parameters:
    - portfolio_values: List of portfolio values over time
    - risk_free_rate: Annual risk-free rate (default 2%)

    Returns:
    - Dictionary with risk metrics
    """
    try:
        # Convert to numpy array and ensure it's properly shaped
        values = np.array(portfolio_values)

        # Check if array is empty or improperly shaped
        if values.size == 0 or (values.ndim > 1 and 0 in values.shape):
            return default_risk_metrics()

        # Ensure we have a 1D array
        if values.ndim > 1:
            values = values.flatten()

        # Check if we have enough data
        if len(values) <= 1:
            return default_risk_metrics()

        # Calculate returns
        returns = np.diff(values) / values[:-1]

        # Calculate metrics
        mean_return = np.mean(returns) * 252  # Annualize daily return
        volatility = np.std(returns) * np.sqrt(252)  # Annualize volatility

        # Sharpe ratio
        sharpe_ratio = (mean_return - risk_free_rate) / volatility if volatility > 0 else 0

        # Maximum drawdown
        peak = np.maximum.accumulate(values)
        drawdown = (peak - values) / peak
        max_drawdown = np.max(drawdown)

        # Sortino ratio (downside risk only)
        downside_returns = returns[returns < 0]
        downside_deviation = np.std(downside_returns) * np.sqrt(252) if len(downside_returns) > 0 else 0
        sortino_ratio = (mean_return - risk_free_rate) / downside_deviation if downside_deviation > 0 else 0

        return {
            'annualized_return': mean_return,
            'annualized_volatility': volatility,
            'sharpe_ratio': sharpe_ratio,
            'max_drawdown': max_drawdown,
            'sortino_ratio': sortino_ratio
        }
    except Exception as e:
        print(f"Warning: Error calculating risk metrics: {str(e)}")
        return default_risk_metrics()

def default_risk_metrics():
    """Return default risk metrics when calculation fails"""
    return {
        'annualized_return': 0,
        'annualized_volatility': 0,
        'sharpe_ratio': 0,
        'max_drawdown': 0,
        'sortino_ratio': 0
    }

# Make sure arrays are 1D for plotting
def ensure_1d_array(arr):
    """Ensure the array is 1D for plotting"""
    try:
        if isinstance(arr, (list, np.ndarray)):
            arr = np.asarray(arr)
            if arr.ndim > 1:
                arr = arr.flatten()  # Flatten to 1D
            if arr.size == 0:  # Check for empty array
                arr = np.array([INITIAL_CAPITAL])  # Default value
        return arr
    except Exception as e:
        print(f"Error converting to 1D array: {str(e)}")
        return np.array([INITIAL_CAPITAL])  # Return a default array

def plot_tv_annual_returns(results, strategy_names, ticker=None, pairs_results=None, pair_name=None):
    """
    繪製temporal validation結果，X軸為TV(訓練年數)，Y軸為年報酬率
    """
    plt.figure(figsize=(12, 6))

    # 繪製單一股票的圖表
    if ticker is not None:
        for strategy in strategy_names:
            x_values = []
            y_values = []
            for train_years in range(1, 10):
                if (strategy in results[ticker]['temporal_validation'] and
                    train_years in results[ticker]['temporal_validation'][strategy] and
                    results[ticker]['temporal_validation'][strategy][train_years] is not None):
                    x_values.append(train_years)
                    y_values.append(results[ticker]['temporal_validation'][strategy][train_years]['annual_return'])

            if x_values and y_values:
                plt.plot(x_values, y_values, marker='o', label=f'{strategy}')

        plt.title(f'Temporal Validation Annual Returns for {ticker}')
    elif pair_name is not None and pairs_results is not None:
        # 繪製特定配對的圖表
        x_values = []
        y_values = []
        for train_years in range(1, 10):
            if (train_years in pairs_results[pair_name]['temporal_validation'] and
                pairs_results[pair_name]['temporal_validation'][train_years] is not None):
                x_values.append(train_years)
                y_values.append(pairs_results[pair_name]['temporal_validation'][train_years]['annual_return'])

        if x_values and y_values:
            plt.plot(x_values, y_values, marker='o', label=f'Pairs Trading')

        plt.title(f'Temporal Validation Annual Returns for Pair {pair_name}')
    else:
        # 繪製所有股票的平均值
        for strategy in strategy_names:
            x_values = list(range(1, 10))
            y_values = [0] * 9  # 初始化為零
            count = [0] * 9     # 計算有效回報以進行平均

            for ticker in results:
                for train_years in range(1, 10):
                    if (strategy in results[ticker]['temporal_validation'] and
                        train_years in results[ticker]['temporal_validation'][strategy] and
                        results[ticker]['temporal_validation'][strategy][train_years] is not None):
                        y_values[train_years-1] += results[ticker]['temporal_validation'][strategy][train_years]['annual_return']
                        count[train_years-1] += 1

            # 計算每個TV的平均值
            for i in range(9):
                if count[i] > 0:
                    y_values[i] /= count[i]

            plt.plot(x_values, y_values, marker='o', label=f'{strategy}')

        plt.title('Average Temporal Validation Annual Returns Across All Stocks')

    # 圖表格式化
    plt.xlabel('Temporal Validation (Training Years)')
    plt.ylabel('Annual Return')
    plt.grid(True)
    plt.legend()
    plt.xticks(range(1, 10))

    # 將y軸格式化為百分比
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.2%}'.format(y)))

    # 儲存圖表
    if ticker is not None:
        plt.savefig(f"results/{ticker}_tv_annual_returns.png")
    elif pair_name is not None:
        plt.savefig(f"results/{pair_name}_tv_annual_returns.png")
    else:
        plt.savefig(f"results/average_tv_annual_returns.png")

    plt.show()



# Main execution
def main():
    results = {}
    pairs_results = {}

    # Problem 1: Evaluate strategies for each stock
    for ticker in TICKERS:
        print(f"\n=== Analyzing {ticker} ===")

        # Get price data
        prices = stock_data[ticker]['Close'].values
        trading_years = (len(prices) - 1) / 252  # Approximate years of data

        # Prepare data for LSTM
        scaler = MinMaxScaler()
        data_scaled = scaler.fit_transform(prices.reshape(-1, 1))

        # Train LSTM model
        print("Training LSTM model...")
        seq_len = 30
        model, X, y = train_lstm_model(data_scaled, seq_len, epochs=20)

        # Implement strategies
        print("Implementing investment strategies...")
        lump_sum_values = lump_sum_strategy(prices)
        dca_values = dca_strategy(prices)
        lstm_values = lstm_strategy(model, data_scaled, scaler, INITIAL_CAPITAL, seq_len)
        ma_values = moving_average_strategy(prices)
        enhanced_ma_values = enhanced_ma_rsi_strategy(prices)

        # Calculate annual returns
        lump_sum_annual = calculate_annual_return(lump_sum_values[-1], INITIAL_CAPITAL, trading_years)
        dca_annual = calculate_annual_return(dca_values[-1], INITIAL_CAPITAL, trading_years)
        lstm_annual = calculate_annual_return(lstm_values[-1], INITIAL_CAPITAL, trading_years)
        ma_annual = calculate_annual_return(ma_values[-1], INITIAL_CAPITAL, trading_years)
        enhanced_ma_annual = calculate_annual_return(enhanced_ma_values[-1], INITIAL_CAPITAL, trading_years)

        # Calculate risk metrics
        lump_sum_risk = calculate_risk_metrics(lump_sum_values)
        dca_risk = calculate_risk_metrics(dca_values)
        lstm_risk = calculate_risk_metrics(lstm_values)
        ma_risk = calculate_risk_metrics(ma_values)
        enhanced_ma_risk = calculate_risk_metrics(enhanced_ma_values)

        print(f"Lump Sum Annual Return: {lump_sum_annual:.2%}")
        print(f"DCA Annual Return: {dca_annual:.2%}")
        print(f"LSTM Strategy Annual Return: {lstm_annual:.2%}")
        print(f"Moving Average Annual Return: {ma_annual:.2%}")
        print(f"Enhanced MA-RSI Annual Return: {enhanced_ma_annual:.2%}")

        # Store results
        results[ticker] = {
            'lump_sum': {'values': lump_sum_values, 'annual_return': lump_sum_annual, 'risk': lump_sum_risk},
            'dca': {'values': dca_values, 'annual_return': dca_annual, 'risk': dca_risk},
            'lstm': {'values': lstm_values, 'annual_return': lstm_annual, 'risk': lstm_risk},
            'moving_average': {'values': ma_values, 'annual_return': ma_annual, 'risk': ma_risk},
            'enhanced_ma': {'values': enhanced_ma_values, 'annual_return': enhanced_ma_annual, 'risk': enhanced_ma_risk},
            'temporal_validation': {}
        }

        # Temporal validation
        print("Performing temporal validation...")
        # For each strategy
        for strategy_name, strategy_func in [
             ('lump_sum', lump_sum_strategy),
             ('dca', dca_strategy),
             ('moving_average', moving_average_strategy),
             ('lstm', lstm_strategy),
             ('enhanced_ma_rsi', enhanced_ma_rsi_strategy)  # 如果這個函數存在的話
        ]:
            results[ticker]['temporal_validation'][strategy_name] = {}

            # Different training/testing splits
            for train_years in range(1, 10):  # 1 to 4 years of training
                # Only pass seq_len to lstm_strategy
                strategy_params = {}
                if strategy_func == lstm_strategy:
                    strategy_params['seq_len'] = seq_len

                tv_result = temporal_validation(
                    prices,
                    strategy_func,
                    train_years,
                    1,  # Test on 1 year
                    **strategy_params
                )

                if tv_result:
                    results[ticker]['temporal_validation'][strategy_name][train_years] = tv_result
                    print(f"  TV{train_years} {strategy_name} annual return: {tv_result['annual_return']:.2%}")

        # Visualize strategies - using ensure_1d_array to prevent plotting errors
        try:
            plt.figure(figsize=(12, 6))

            # Ensure arrays are 1D for plotting
            lump_sum_values_1d = ensure_1d_array(lump_sum_values)
            dca_values_1d = ensure_1d_array(dca_values)
            lstm_values_1d = ensure_1d_array(lstm_values)
            ma_values_1d = ensure_1d_array(ma_values)
            enhanced_ma_values_1d = ensure_1d_array(enhanced_ma_values)

            plt.plot(lump_sum_values_1d, label=f'Lump Sum ({lump_sum_annual:.2%})')
            plt.plot(dca_values_1d, label=f'DCA ({dca_annual:.2%})')
            plt.plot(lstm_values_1d, label=f'LSTM Strategy ({lstm_annual:.2%})')
            plt.plot(ma_values_1d, label=f'Moving Average ({ma_annual:.2%})')
            plt.plot(enhanced_ma_values_1d, label=f'Enhanced MA-RSI ({enhanced_ma_annual:.2%})')
            plt.title(f"Investment Strategies for {ticker}")
            plt.xlabel("Trading Days")
            plt.ylabel("Portfolio Value ($)")
            plt.legend()
            plt.grid(True)
            plt.savefig(f"results/{ticker}_strategies.png")
            plt.show()
        except Exception as e:
            print(f"Error plotting strategy results: {str(e)}")

    # Problem 2: Pairs Trading
    print("\n=== Evaluating Pairs Trading ===")

    # Try all possible pairs
    for i in range(len(TICKERS)):
        for j in range(i+1, len(TICKERS)):
            ticker1 = TICKERS[i]
            ticker2 = TICKERS[j]
            pair_name = f"{ticker1}-{ticker2}"

            print(f"\nAnalyzing pair: {pair_name}")

            # Get prices
            stock1_prices = stock_data[ticker1]['Close'].values
            stock2_prices = stock_data[ticker2]['Close'].values

            # Calculate pairs trading
            try:
                portfolio_values = pairs_trading_strategy(stock1_prices, stock2_prices)

                # Calculate annual return
                min_len = min(len(stock1_prices), len(stock2_prices))
                trading_years = min_len / 252
                annual_return = calculate_annual_return(portfolio_values[-1], INITIAL_CAPITAL, trading_years)

                # Calculate risk metrics
                risk_metrics = calculate_risk_metrics(portfolio_values)

                print(f"Pairs Trading Annual Return: {annual_return:.2%}")
                print(f"Sharpe Ratio: {risk_metrics['sharpe_ratio']:.2f}")
                print(f"Maximum Drawdown: {risk_metrics['max_drawdown']:.2%}")

                # Store results
                pairs_results[pair_name] = {
                    'portfolio_values': portfolio_values,
                    'annual_return': annual_return,
                    'risk_metrics': risk_metrics,
                    'temporal_validation': {}
                }

                # Temporal validation for pairs trading
                print("Performing temporal validation for pairs trading...")

                for train_years in range(1, 10):  # 1 to 4 years of training
                    # Use the pairs trading temporal validation function
                    tv_result = pairs_trading_temporal_validation(
                        stock1_prices,
                        stock2_prices,
                        train_years
                    )

                    if tv_result:
                        pairs_results[pair_name]['temporal_validation'][train_years] = tv_result
                        print(f"  TV{train_years} annual return: {tv_result['annual_return']:.2%}")

                # Visualize pairs trading - ensure 1D array for plotting
                try:
                    plt.figure(figsize=(12, 6))
                    portfolio_values_1d = ensure_1d_array(portfolio_values)
                    plt.plot(portfolio_values_1d, label=f'Pairs Trading ({annual_return:.2%})')
                    plt.title(f"Pairs Trading: {pair_name}")
                    plt.xlabel("Trading Days")
                    plt.ylabel("Portfolio Value ($)")
                    plt.legend()
                    plt.grid(True)
                    plt.savefig(f"results/{pair_name}_pairs_trading.png")
                    plt.show()

                    # Plot the spread and z-score
                    plt.figure(figsize=(12, 6))

                    # Calculate hedge ratio, spread, and z-score for visualization
                    hedge_ratio = calculate_hedge_ratio(stock1_prices, stock2_prices)
                    spread = stock2_prices - hedge_ratio * stock1_prices

                    # Handle zero standard deviation
                    spread_std = np.std(spread)
                    if spread_std == 0:
                        spread_std = 0.00001

                    z_score = (spread - np.mean(spread)) / spread_std

                    plt.subplot(2, 1, 1)
                    plt.plot(spread)
                    plt.title(f"{pair_name} Spread")
                    plt.axhline(y=np.mean(spread), color='r', linestyle='-')
                    plt.axhline(y=np.mean(spread) + 2*np.std(spread), color='g', linestyle='--')
                    plt.axhline(y=np.mean(spread) - 2*np.std(spread), color='g', linestyle='--')

                    plt.subplot(2, 1, 2)
                    plt.plot(z_score)
                    plt.title(f"{pair_name} Z-Score")
                    plt.axhline(y=0, color='r', linestyle='-')
                    plt.axhline(y=2, color='g', linestyle='--')
                    plt.axhline(y=-2, color='g', linestyle='--')

                    plt.tight_layout()
                    plt.savefig(f"results/{pair_name}_spread_zscore.png")
                    plt.show()
                except Exception as e:
                    print(f"Error plotting pairs trading results: {str(e)}")
                    plot_tv_annual_returns(results, ['lump_sum', 'dca', 'moving_average', 'lstm', 'enhanced_ma_rsi'], ticker=ticker)
                    plot_tv_annual_returns(None, [], pairs_results=pairs_results, pair_name=pair_name)

            except Exception as e:
                print(f"Error analyzing pair {pair_name}: {str(e)}")
                plot_tv_annual_returns(results, ['lump_sum', 'dca', 'moving_average', 'lstm', 'enhanced_ma_rsi'], ticker=ticker)

    # Print summary of results
    print("\n=== SUMMARY OF RESULTS ===")

    # Create summary table for individual stock strategies
    print("\nIndividual Stock Strategies:")
    summary_data = []
    for ticker in TICKERS:
        ticker_data = [
            ticker,
            f"{results[ticker]['lump_sum']['annual_return']:.2%}",
            f"{results[ticker]['dca']['annual_return']:.2%}",
            f"{results[ticker]['moving_average']['annual_return']:.2%}",
            f"{results[ticker]['enhanced_ma']['annual_return']:.2%}",
            f"{results[ticker]['lstm']['annual_return']:.2%}"
        ]
        summary_data.append(ticker_data)
        plot_tv_annual_returns(results, ['lump_sum', 'dca', 'moving_average', 'lstm', 'enhanced_ma_rsi'], ticker=ticker)
    summary_df = pd.DataFrame(
        summary_data,
        columns=['Ticker', 'Lump Sum', 'DCA', 'Moving Average', 'Enhanced MA-RSI', 'LSTM']
    )
    print(summary_df.to_string(index=False))

    # Save summary table to CSV
    summary_df.to_csv("results/stock_strategies_summary.csv", index=False)

    # Create summary table for pairs trading
    print("\nPairs Trading Strategies:")
    pairs_data = []
    for pair_name, pair_result in pairs_results.items():
        pair_data = [
            pair_name,
            f"{pair_result['annual_return']:.2%}",
            f"{pair_result['risk_metrics']['sharpe_ratio']:.2f}",
            f"{pair_result['risk_metrics']['max_drawdown']:.2%}"
        ]
        pairs_data.append(pair_data)

    pairs_df = pd.DataFrame(
        pairs_data,
        columns=['Pair', 'Annual Return', 'Sharpe Ratio', 'Max Drawdown']
    )
    print(pairs_df.to_string(index=False))

    # Save pairs summary to CSV
    pairs_df.to_csv("results/pairs_trading_summary.csv", index=False)

    # Create temporal validation summary
    for train_years in range(1, 10):
        print(f"\nTemporal Validation (TV{train_years}) Summary:")
        tv_data = []

        for ticker in TICKERS:
            ticker_tv = []
            for strategy in ['moving_average', 'enhanced_ma', 'lstm']:
                if (strategy in results[ticker]['temporal_validation'] and
                    train_years in results[ticker]['temporal_validation'][strategy] and
                    results[ticker]['temporal_validation'][strategy][train_years] is not None):
                    annual_return = results[ticker]['temporal_validation'][strategy][train_years]['annual_return']
                    ticker_tv.append(f"{annual_return:.2%}")
                else:
                    ticker_tv.append("N/A")

            tv_data.append([ticker] + ticker_tv)

        tv_df = pd.DataFrame(
            tv_data,
            columns=['Ticker', 'Moving Average', 'Enhanced MA-RSI', 'LSTM']
        )
        print(tv_df.to_string(index=False))

        # Save TV summary to CSV
        tv_df.to_csv(f"results/tv{train_years}_summary.csv", index=False)

    # Pairs trading temporal validation summary
    for train_years in range(1, 10):
        print(f"\nPairs Trading Temporal Validation (TV{train_years}) Summary:")
        tv_pairs_data = []

        for pair_name, pair_result in pairs_results.items():
            if (train_years in pair_result['temporal_validation'] and
                pair_result['temporal_validation'][train_years] is not None):
                annual_return = pair_result['temporal_validation'][train_years]['annual_return']
                tv_pairs_data.append([pair_name, f"{annual_return:.2%}"])
            else:
                tv_pairs_data.append([pair_name, "N/A"])

        tv_pairs_df = pd.DataFrame(
            tv_pairs_data,
            columns=['Pair', 'Annual Return']
        )
        print(tv_pairs_df.to_string(index=False))

        # Save pairs TV summary to CSV
        tv_pairs_df.to_csv(f"results/pairs_tv{train_years}_summary.csv", index=False)




if __name__ == "__main__":
    main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching stock data...
# Downloaded data for AAPL: 2516 trading days
# Downloaded data for MSFT: 2516 trading days
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloaded data for JPM: 2516 trading days
# Downloaded data for PFE: 2516 trading days
# Downloaded data for XOM: 2516 trading days
#
# === Analyzing AAPL ===
# Training LSTM model...
# Epoch 0, Loss: 0.1316
# Epoch 5, Loss: 0.0553
# Epoch 10, Loss: 0.0346
# Epoch 15, Loss: 0.0100
# Implementing investment strategies...
# Lump Sum Annual Return: 21.79%
# DCA Annual Return: 14.91%
# LSTM Strategy Annual Return: 10.98%
# Moving Average Annual Return: 12.10%
# Enhanced MA-RSI Annual Return: 5.91%
# Performing temporal validation...
#   TV1 lump_sum annual return: 29.17%
#   TV2 lump_sum annual return: 25.84%
#   TV3 lump_sum annual return: 15.04%
#   TV4 lump_sum annual return: 44.62%
#   TV5 lump_sum annual return: 89.11%
#   TV6 lump_sum annual return: 27.77%
#   TV7 lump_sum annual return: 0.57%
#   TV8 lump_sum annual return: 1.46%
#   TV1 dca annual return: 29.42%
#   TV2 dca annual return: 9.91%
#   TV3 dca annual return: 6.87%
#   TV4 dca annual return: 23.43%
#   TV5 dca annual return: 28.41%
#   TV6 dca annual return: 14.72%
#   TV7 dca annual return: 11.36%
#   TV8 dca annual return: -7.11%
#   TV1 moving_average annual return: 35.24%
#   TV2 moving_average annual return: -6.23%
#   TV3 moving_average annual return: 31.06%
#   TV4 moving_average annual return: 44.72%
#   TV5 moving_average annual return: 30.89%
#   TV6 moving_average annual return: 19.63%
#   TV7 moving_average annual return: -7.84%
#   TV8 moving_average annual return: -9.11%
# Epoch 0, Loss: 0.2244
# Epoch 5, Loss: 0.0532
# Epoch 10, Loss: 0.0564
# Epoch 15, Loss: 0.0339
#   TV1 lstm annual return: -1.73%
# Epoch 0, Loss: 0.0986
# Epoch 5, Loss: 0.0438
# Epoch 10, Loss: 0.0132
# Epoch 15, Loss: 0.0068
#   TV2 lstm annual return: 36.14%
# Epoch 0, Loss: 0.1800
# Epoch 5, Loss: 0.0655
# Epoch 10, Loss: 0.0249
# Epoch 15, Loss: 0.0160
#   TV3 lstm annual return: 63.85%
# Epoch 0, Loss: 0.1395
# Epoch 5, Loss: 0.0436
# Epoch 10, Loss: 0.0208
# Epoch 15, Loss: 0.0086
#   TV4 lstm annual return: 30.16%
# Epoch 0, Loss: 0.1252
# Epoch 5, Loss: 0.0487
# Epoch 10, Loss: 0.0318
# Epoch 15, Loss: 0.0157
#   TV5 lstm annual return: 114.58%
# Epoch 0, Loss: 0.0722
# Epoch 5, Loss: 0.0374
# Epoch 10, Loss: 0.0053
# Epoch 15, Loss: 0.0016
#   TV6 lstm annual return: 154.88%
# Epoch 0, Loss: 0.0920
# Epoch 5, Loss: 0.0325
# Epoch 10, Loss: 0.0279
# Epoch 15, Loss: 0.0080
#   TV7 lstm annual return: 185.63%
# Epoch 0, Loss: 0.1529
# Epoch 5, Loss: 0.0631
# Epoch 10, Loss: 0.0259
# Epoch 15, Loss: 0.0055
#   TV8 lstm annual return: 228.52%
#   TV1 enhanced_ma_rsi annual return: 15.94%
#   TV2 enhanced_ma_rsi annual return: -0.74%
#   TV3 enhanced_ma_rsi annual return: 11.71%
#   TV4 enhanced_ma_rsi annual return: 25.08%
#   TV5 enhanced_ma_rsi annual return: 30.34%
#   TV6 enhanced_ma_rsi annual return: 12.81%
#   TV7 enhanced_ma_rsi annual return: -7.74%
#   TV8 enhanced_ma_rsi annual return: -11.24%
# === Analyzing MSFT ===
# Training LSTM model...
# Epoch 0, Loss: 0.2681
# Epoch 5, Loss: 0.1176
# Epoch 10, Loss: 0.0614
# Epoch 15, Loss: 0.0311
# Implementing investment strategies...
# Lump Sum Annual Return: 26.73%
# DCA Annual Return: 14.92%
# LSTM Strategy Annual Return: 1.32%
# Moving Average Annual Return: 11.68%
# Enhanced MA-RSI Annual Return: 8.21%
# Performing temporal validation...
#   TV1 lump_sum annual return: 20.93%
#   TV2 lump_sum annual return: 46.31%
#   TV3 lump_sum annual return: 30.71%
#   TV4 lump_sum annual return: 44.20%
#   TV5 lump_sum annual return: 48.07%
#   TV6 lump_sum annual return: 11.21%
#   TV7 lump_sum annual return: 4.22%
#   TV8 lump_sum annual return: 43.99%
#   TV1 dca annual return: 15.12%
#   TV2 dca annual return: 21.11%
#   TV3 dca annual return: 15.34%
#   TV4 dca annual return: 21.66%
#   TV5 dca annual return: 25.28%
#   TV6 dca annual return: -0.27%
#   TV7 dca annual return: 12.86%
#   TV8 dca annual return: 18.47%
#   TV1 moving_average annual return: 18.22%
#   TV2 moving_average annual return: 30.64%
#   TV3 moving_average annual return: 15.33%
#   TV4 moving_average annual return: 14.82%
#   TV5 moving_average annual return: 19.37%
#   TV6 moving_average annual return: -2.90%
#   TV7 moving_average annual return: -15.58%
#   TV8 moving_average annual return: 17.37%
# Epoch 0, Loss: 0.4245
# Epoch 5, Loss: 0.0573
# Epoch 10, Loss: 0.0505
# Epoch 15, Loss: 0.0404
#   TV1 lstm annual return: -18.03%
# Epoch 0, Loss: 0.4368
# Epoch 5, Loss: 0.1336
# Epoch 10, Loss: 0.0638
# Epoch 15, Loss: 0.0497
#   TV2 lstm annual return: 12.17%
# Epoch 0, Loss: 0.1260
# Epoch 5, Loss: 0.0512
# Epoch 10, Loss: 0.0385
# Epoch 15, Loss: 0.0169
#   TV3 lstm annual return: 1.89%
# Epoch 0, Loss: 0.3033
# Epoch 5, Loss: 0.0849
# Epoch 10, Loss: 0.0577
# Epoch 15, Loss: 0.0272
#   TV4 lstm annual return: 13.67%
# Epoch 0, Loss: 0.1411
# Epoch 5, Loss: 0.0530
# Epoch 10, Loss: 0.0321
# Epoch 15, Loss: 0.0169
#   TV5 lstm annual return: 2.27%
# Epoch 0, Loss: 0.2550
# Epoch 5, Loss: 0.0773
# Epoch 10, Loss: 0.0488
# Epoch 15, Loss: 0.0335
#   TV6 lstm annual return: 35.19%
# Epoch 0, Loss: 0.1954
# Epoch 5, Loss: 0.0564
# Epoch 10, Loss: 0.0399
# Epoch 15, Loss: 0.0153
#   TV7 lstm annual return: 7.19%
# Epoch 0, Loss: 0.3555
# Epoch 5, Loss: 0.0895
# Epoch 10, Loss: 0.0543
# Epoch 15, Loss: 0.0279
#   TV8 lstm annual return: 24.60%
#   TV1 enhanced_ma_rsi annual return: 13.18%
#   TV2 enhanced_ma_rsi annual return: 14.82%
#   TV3 enhanced_ma_rsi annual return: 7.08%
#   TV4 enhanced_ma_rsi annual return: 10.94%
#   TV5 enhanced_ma_rsi annual return: 28.53%
#   TV6 enhanced_ma_rsi annual return: -9.19%
#   TV7 enhanced_ma_rsi annual return: -12.57%
#   TV8 enhanced_ma_rsi annual return: 10.59%
# === Analyzing JPM ===
# Training LSTM model...
# Epoch 0, Loss: 0.1929
# Epoch 5, Loss: 0.0337
# Epoch 10, Loss: 0.0396
# Epoch 15, Loss: 0.0169
# Implementing investment strategies...
# Lump Sum Annual Return: 17.05%
# DCA Annual Return: 10.84%
# LSTM Strategy Annual Return: 12.57%
# Moving Average Annual Return: 11.93%
# Enhanced MA-RSI Annual Return: 7.65%
# Performing temporal validation...
#   TV1 lump_sum annual return: 40.07%
#   TV2 lump_sum annual return: 33.54%
#   TV3 lump_sum annual return: 2.60%
#   TV4 lump_sum annual return: -15.64%
#   TV5 lump_sum annual return: 79.91%
#   TV6 lump_sum annual return: -14.85%
#   TV7 lump_sum annual return: 14.58%
#   TV8 lump_sum annual return: 30.73%
#   TV1 dca annual return: 21.35%
#   TV2 dca annual return: 15.46%
#   TV3 dca annual return: 3.67%
#   TV4 dca annual return: -20.79%
#   TV5 dca annual return: 42.84%
#   TV6 dca annual return: -17.71%
#   TV7 dca annual return: 14.81%
#   TV8 dca annual return: 18.11%
#   TV1 moving_average annual return: 37.53%
#   TV2 moving_average annual return: 14.90%
#   TV3 moving_average annual return: -2.08%
#   TV4 moving_average annual return: 10.99%
#   TV5 moving_average annual return: 49.06%
#   TV6 moving_average annual return: 1.64%
#   TV7 moving_average annual return: -7.81%
#   TV8 moving_average annual return: 21.15%
# Epoch 0, Loss: 0.4967
# Epoch 5, Loss: 0.1329
# Epoch 10, Loss: 0.0613
# Epoch 15, Loss: 0.0348
#   TV1 lstm annual return: -0.02%
# Epoch 0, Loss: 0.3407
# Epoch 5, Loss: 0.0377
# Epoch 10, Loss: 0.0370
# Epoch 15, Loss: 0.0309
#   TV2 lstm annual return: 13.76%
# Epoch 0, Loss: 0.1885
# Epoch 5, Loss: 0.0567
# Epoch 10, Loss: 0.0343
# Epoch 15, Loss: 0.0122
#   TV3 lstm annual return: 20.27%
# Epoch 0, Loss: 0.5508
# Epoch 5, Loss: 0.1933
# Epoch 10, Loss: 0.0774
# Epoch 15, Loss: 0.0433
#   TV4 lstm annual return: 45.38%
# Epoch 0, Loss: 0.3607
# Epoch 5, Loss: 0.0668
# Epoch 10, Loss: 0.0582
# Epoch 15, Loss: 0.0303
#   TV5 lstm annual return: 77.27%
# Epoch 0, Loss: 0.1761
# Epoch 5, Loss: 0.0513
# Epoch 10, Loss: 0.0392
# Epoch 15, Loss: 0.0221
#   TV6 lstm annual return: 111.09%
# Epoch 0, Loss: 0.1596
# Epoch 5, Loss: 0.0654
# Epoch 10, Loss: 0.0410
# Epoch 15, Loss: 0.0200
#   TV7 lstm annual return: 88.18%
# Epoch 0, Loss: 0.1561
# Epoch 5, Loss: 0.0572
# Epoch 10, Loss: 0.0325
# Epoch 15, Loss: 0.0083
#   TV8 lstm annual return: 154.69%
#   TV1 enhanced_ma_rsi annual return: 18.38%
#   TV2 enhanced_ma_rsi annual return: 9.03%
#   TV3 enhanced_ma_rsi annual return: -5.48%
#   TV4 enhanced_ma_rsi annual return: 5.96%
#   TV5 enhanced_ma_rsi annual return: 51.97%
#   TV6 enhanced_ma_rsi annual return: 3.86%
#   TV7 enhanced_ma_rsi annual return: -7.93%
#   TV8 enhanced_ma_rsi annual return: 0.25%
# === Analyzing PFE ===
# Training LSTM model...
# Epoch 0, Loss: 0.0861
# Epoch 5, Loss: 0.0357
# Epoch 10, Loss: 0.0270
# Epoch 15, Loss: 0.0126
# Implementing investment strategies...
# Lump Sum Annual Return: -0.10%
# DCA Annual Return: -2.13%
# LSTM Strategy Annual Return: 6.30%
# Moving Average Annual Return: -2.45%
# Enhanced MA-RSI Annual Return: -4.66%
# Performing temporal validation...
#   TV1 lump_sum annual return: 7.83%
#   TV2 lump_sum annual return: 11.32%
#   TV3 lump_sum annual return: 19.27%
#   TV4 lump_sum annual return: -8.70%
#   TV5 lump_sum annual return: 15.04%
#   TV6 lump_sum annual return: 42.59%
#   TV7 lump_sum annual return: -19.83%
#   TV8 lump_sum annual return: -34.09%
#   TV1 dca annual return: 2.30%
#   TV2 dca annual return: 6.37%
#   TV3 dca annual return: 5.79%
#   TV4 dca annual return: -3.87%
#   TV5 dca annual return: 8.88%
#   TV6 dca annual return: 18.30%
#   TV7 dca annual return: -12.04%
#   TV8 dca annual return: -19.68%
#   TV1 moving_average annual return: 3.06%
#   TV2 moving_average annual return: 2.00%
#   TV3 moving_average annual return: 10.75%
#   TV4 moving_average annual return: -6.24%
#   TV5 moving_average annual return: 3.48%
#   TV6 moving_average annual return: 24.66%
#   TV7 moving_average annual return: -3.64%
#   TV8 moving_average annual return: -12.25%
# Epoch 0, Loss: 0.3601
# Epoch 5, Loss: 0.1005
# Epoch 10, Loss: 0.0524
# Epoch 15, Loss: 0.0385
#   TV1 lstm annual return: -12.62%
# Epoch 0, Loss: 0.2797
# Epoch 5, Loss: 0.0506
# Epoch 10, Loss: 0.0422
# Epoch 15, Loss: 0.0258
#   TV2 lstm annual return: 1.02%
# Epoch 0, Loss: 0.1591
# Epoch 5, Loss: 0.0434
# Epoch 10, Loss: 0.0334
# Epoch 15, Loss: 0.0244
#   TV3 lstm annual return: 16.45%
# Epoch 0, Loss: 0.1053
# Epoch 5, Loss: 0.0410
# Epoch 10, Loss: 0.0283
# Epoch 15, Loss: 0.0069
#   TV4 lstm annual return: 24.86%
# Epoch 0, Loss: 0.1849
# Epoch 5, Loss: 0.0562
# Epoch 10, Loss: 0.0353
# Epoch 15, Loss: 0.0147
#   TV5 lstm annual return: 15.48%
# Epoch 0, Loss: 0.4441
# Epoch 5, Loss: 0.0423
# Epoch 10, Loss: 0.0373
# Epoch 15, Loss: 0.0367
#   TV6 lstm annual return: 46.32%
# Epoch 0, Loss: 0.1493
# Epoch 5, Loss: 0.0369
# Epoch 10, Loss: 0.0289
# Epoch 15, Loss: 0.0167
#   TV7 lstm annual return: 94.83%
# Epoch 0, Loss: 0.1988
# Epoch 5, Loss: 0.0428
# Epoch 10, Loss: 0.0370
# Epoch 15, Loss: 0.0227
#   TV8 lstm annual return: 35.11%
#   TV1 enhanced_ma_rsi annual return: 2.16%
#   TV2 enhanced_ma_rsi annual return: 4.59%
#   TV3 enhanced_ma_rsi annual return: -4.44%
#   TV4 enhanced_ma_rsi annual return: -3.15%
#   TV5 enhanced_ma_rsi annual return: 8.63%
#   TV6 enhanced_ma_rsi annual return: 1.25%
#   TV7 enhanced_ma_rsi annual return: -2.82%
#   TV8 enhanced_ma_rsi annual return: -12.25%
# === Analyzing XOM ===
# Training LSTM model...
# Epoch 0, Loss: 0.2277
# Epoch 5, Loss: 0.0529
# Epoch 10, Loss: 0.0421
# Epoch 15, Loss: 0.0247
# Implementing investment strategies...
# Lump Sum Annual Return: 6.17%
# DCA Annual Return: 6.08%
# LSTM Strategy Annual Return: 2.86%
# Moving Average Annual Return: 1.83%
# Enhanced MA-RSI Annual Return: 2.96%
# Performing temporal validation...
#   TV1 lump_sum annual return: 0.56%
#   TV2 lump_sum annual return: -0.98%
#   TV3 lump_sum annual return: 7.03%
#   TV4 lump_sum annual return: -47.59%
#   TV5 lump_sum annual return: 57.57%
#   TV6 lump_sum annual return: 61.69%
#   TV7 lump_sum annual return: 35.32%
#   TV8 lump_sum annual return: 5.08%
#   TV1 dca annual return: -3.41%
#   TV2 dca annual return: -2.04%
#   TV3 dca annual return: 3.74%
#   TV4 dca annual return: -37.30%
#   TV5 dca annual return: 38.42%
#   TV6 dca annual return: 41.05%
#   TV7 dca annual return: 18.30%
#   TV8 dca annual return: 13.07%
#   TV1 moving_average annual return: -3.21%
#   TV2 moving_average annual return: -5.14%
#   TV3 moving_average annual return: -1.00%
#   TV4 moving_average annual return: -15.73%
#   TV5 moving_average annual return: 54.02%
#   TV6 moving_average annual return: 16.85%
#   TV7 moving_average annual return: -8.34%
#   TV8 moving_average annual return: 16.29%
# Epoch 0, Loss: 0.5933
# Epoch 5, Loss: 0.0572
# Epoch 10, Loss: 0.0286
# Epoch 15, Loss: 0.0410
#   TV1 lstm annual return: -5.03%
# Epoch 0, Loss: 0.2862
# Epoch 5, Loss: 0.0583
# Epoch 10, Loss: 0.0502
# Epoch 15, Loss: 0.0272
#   TV2 lstm annual return: -18.41%
# Epoch 0, Loss: 0.5584
# Epoch 5, Loss: 0.0327
# Epoch 10, Loss: 0.0320
# Epoch 15, Loss: 0.0243
#   TV3 lstm annual return: -8.98%
# Epoch 0, Loss: 0.5747
# Epoch 5, Loss: 0.2597
# Epoch 10, Loss: 0.0635
# Epoch 15, Loss: 0.0377
#   TV4 lstm annual return: -14.86%
# Epoch 0, Loss: 0.6999
# Epoch 5, Loss: 0.2292
# Epoch 10, Loss: 0.0575
# Epoch 15, Loss: 0.0252
#   TV5 lstm annual return: -13.84%
# Epoch 0, Loss: 0.3953
# Epoch 5, Loss: 0.0766
# Epoch 10, Loss: 0.0553
# Epoch 15, Loss: 0.0309
#   TV6 lstm annual return: 19.89%
# Epoch 0, Loss: 0.1452
# Epoch 5, Loss: 0.0286
# Epoch 10, Loss: 0.0267
# Epoch 15, Loss: 0.0182
#   TV7 lstm annual return: 10.93%
# Epoch 0, Loss: 0.1392
# Epoch 5, Loss: 0.0417
# Epoch 10, Loss: 0.0261
# Epoch 15, Loss: 0.0181
#   TV8 lstm annual return: 51.88%
#   TV1 enhanced_ma_rsi annual return: -4.18%
#   TV2 enhanced_ma_rsi annual return: -5.67%
#   TV3 enhanced_ma_rsi annual return: -5.77%
#   TV4 enhanced_ma_rsi annual return: -15.73%
#   TV5 enhanced_ma_rsi annual return: 53.28%
#   TV6 enhanced_ma_rsi annual return: 14.61%
#   TV7 enhanced_ma_rsi annual return: -4.27%
#   TV8 enhanced_ma_rsi annual return: 10.66%
# === Evaluating Pairs Trading ===
#
# Analyzing pair: AAPL-MSFT
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -0.78%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: -1.09%
#   TV2 annual return: 1.61%
#   TV3 annual return: -5.89%
#   TV4 annual return: -4.08%
#   TV5 annual return: -0.81%
#   TV6 annual return: -5.70%
#   TV7 annual return: -5.68%
#   TV8 annual return: -6.32%
#   TV9 annual return: -12.93%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: AAPL-JPM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -1.17%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: -12.26%
#   TV2 annual return: 2.75%
#   TV3 annual return: 7.17%
#   TV4 annual return: 6.71%
#   TV5 annual return: 1.15%
#   TV6 annual return: -3.48%
#   TV7 annual return: -6.65%
#   TV8 annual return: 1.44%
#   TV9 annual return: -8.59%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: AAPL-PFE
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -2.28%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 8.58%
#   TV2 annual return: -1.15%
#   TV3 annual return: 3.48%
#   TV4 annual return: 14.34%
#   TV5 annual return: 6.55%
#   TV6 annual return: 0.08%
#   TV7 annual return: 5.04%
#   TV8 annual return: 12.55%
#   TV9 annual return: 16.74%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: AAPL-XOM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -0.80%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 2.66%
#   TV2 annual return: 8.38%
#   TV3 annual return: 5.62%
#   TV4 annual return: 6.39%
#   TV5 annual return: 8.07%
#   TV6 annual return: 7.19%
#   TV7 annual return: 0.81%
#   TV8 annual return: -14.13%
#   TV9 annual return: -2.96%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: MSFT-JPM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: 0.07%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 0.00%
#   TV2 annual return: 6.23%
#   TV3 annual return: 8.51%
#   TV4 annual return: 3.68%
#   TV5 annual return: -5.97%
#   TV6 annual return: 0.46%
#   TV7 annual return: -0.50%
#   TV8 annual return: 3.52%
#   TV9 annual return: 6.02%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: MSFT-PFE
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -1.25%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 0.00%
#   TV2 annual return: -1.86%
#   TV3 annual return: 1.55%
#   TV4 annual return: 10.48%
#   TV5 annual return: 1.32%
#   TV6 annual return: 3.58%
#   TV7 annual return: 4.07%
#   TV8 annual return: 13.54%
#   TV9 annual return: -0.68%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: MSFT-XOM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -1.54%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: -4.39%
#   TV2 annual return: 8.28%
#   TV3 annual return: 1.18%
#   TV4 annual return: 6.28%
#   TV5 annual return: 3.27%
#   TV6 annual return: 5.32%
#   TV7 annual return: -2.10%
#   TV8 annual return: -13.96%
#   TV9 annual return: -1.99%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: JPM-PFE
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -0.97%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 1.85%
#   TV2 annual return: -5.20%
#   TV3 annual return: 0.76%
#   TV4 annual return: 5.33%
#   TV5 annual return: 4.37%
#   TV6 annual return: 6.25%
#   TV7 annual return: 10.33%
#   TV8 annual return: 20.15%
#   TV9 annual return: 19.77%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: JPM-XOM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -1.05%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: -1.04%
#   TV2 annual return: -4.35%
#   TV3 annual return: -1.27%
#   TV4 annual return: -1.28%
#   TV5 annual return: -0.46%
#   TV6 annual return: -0.57%
#   TV7 annual return: -13.17%
#   TV8 annual return: -12.45%
#   TV9 annual return: 0.00%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Analyzing pair: PFE-XOM
# Warning: Error calculating risk metrics: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# Pairs Trading Annual Return: -0.54%
# Sharpe Ratio: 0.00
# Maximum Drawdown: 0.00%
# Performing temporal validation for pairs trading...
#   TV1 annual return: 0.02%
#   TV2 annual return: 1.29%
#   TV3 annual return: 3.87%
#   TV4 annual return: 6.32%
#   TV5 annual return: 2.19%
#   TV6 annual return: 13.28%
#   TV7 annual return: 11.97%
#   TV8 annual return: 8.13%
#   TV9 annual return: -0.64%
# Error converting to 1D array: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2516,) + inhomogeneous part.
# === SUMMARY OF RESULTS ===
#
# Individual Stock Strategies:
# Ticker Lump Sum    DCA Moving Average Enhanced MA-RSI   LSTM
#   AAPL   21.79% 14.91%         12.10%           5.91% 10.98%
#   MSFT   26.73% 14.92%         11.68%           8.21%  1.32%
#    JPM   17.05% 10.84%         11.93%           7.65% 12.57%
#    PFE   -0.10% -2.13%         -2.45%          -4.66%  6.30%
#    XOM    6.17%  6.08%          1.83%           2.96%  2.86%
#
# Pairs Trading Strategies:
#      Pair Annual Return Sharpe Ratio Max Drawdown
# AAPL-MSFT        -0.78%         0.00        0.00%
#  AAPL-JPM        -1.17%         0.00        0.00%
#  AAPL-PFE        -2.28%         0.00        0.00%
#  AAPL-XOM        -0.80%         0.00        0.00%
#  MSFT-JPM         0.07%         0.00        0.00%
#  MSFT-PFE        -1.25%         0.00        0.00%
#  MSFT-XOM        -1.54%         0.00        0.00%
#   JPM-PFE        -0.97%         0.00        0.00%
#   JPM-XOM        -1.05%         0.00        0.00%
#   PFE-XOM        -0.54%         0.00        0.00%
#
# Temporal Validation (TV1) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         35.24%             N/A  -1.73%
#   MSFT         18.22%             N/A -18.03%
#    JPM         37.53%             N/A  -0.02%
#    PFE          3.06%             N/A -12.62%
#    XOM         -3.21%             N/A  -5.03%
#
# Temporal Validation (TV2) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         -6.23%             N/A  36.14%
#   MSFT         30.64%             N/A  12.17%
#    JPM         14.90%             N/A  13.76%
#    PFE          2.00%             N/A   1.02%
#    XOM         -5.14%             N/A -18.41%
#
# Temporal Validation (TV3) Summary:
# Ticker Moving Average Enhanced MA-RSI   LSTM
#   AAPL         31.06%             N/A 63.85%
#   MSFT         15.33%             N/A  1.89%
#    JPM         -2.08%             N/A 20.27%
#    PFE         10.75%             N/A 16.45%
#    XOM         -1.00%             N/A -8.98%
#
# Temporal Validation (TV4) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         44.72%             N/A  30.16%
#   MSFT         14.82%             N/A  13.67%
#    JPM         10.99%             N/A  45.38%
#    PFE         -6.24%             N/A  24.86%
#    XOM        -15.73%             N/A -14.86%
#
# Temporal Validation (TV5) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         30.89%             N/A 114.58%
#   MSFT         19.37%             N/A   2.27%
#    JPM         49.06%             N/A  77.27%
#    PFE          3.48%             N/A  15.48%
#    XOM         54.02%             N/A -13.84%
#
# Temporal Validation (TV6) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         19.63%             N/A 154.88%
#   MSFT         -2.90%             N/A  35.19%
#    JPM          1.64%             N/A 111.09%
#    PFE         24.66%             N/A  46.32%
#    XOM         16.85%             N/A  19.89%
#
# Temporal Validation (TV7) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         -7.84%             N/A 185.63%
#   MSFT        -15.58%             N/A   7.19%
#    JPM         -7.81%             N/A  88.18%
#    PFE         -3.64%             N/A  94.83%
#    XOM         -8.34%             N/A  10.93%
#
# Temporal Validation (TV8) Summary:
# Ticker Moving Average Enhanced MA-RSI    LSTM
#   AAPL         -9.11%             N/A 228.52%
#   MSFT         17.37%             N/A  24.60%
#    JPM         21.15%             N/A 154.69%
#    PFE        -12.25%             N/A  35.11%
#    XOM         16.29%             N/A  51.88%
#
# Temporal Validation (TV9) Summary:
# Ticker Moving Average Enhanced MA-RSI LSTM
#   AAPL            N/A             N/A  N/A
#   MSFT            N/A             N/A  N/A
#    JPM            N/A             N/A  N/A
#    PFE            N/A             N/A  N/A
#    XOM            N/A             N/A  N/A
#
# Pairs Trading Temporal Validation (TV1) Summary:
#      Pair Annual Return
# AAPL-MSFT        -1.09%
#  AAPL-JPM       -12.26%
#  AAPL-PFE         8.58%
#  AAPL-XOM         2.66%
#  MSFT-JPM         0.00%
#  MSFT-PFE         0.00%
#  MSFT-XOM        -4.39%
#   JPM-PFE         1.85%
#   JPM-XOM        -1.04%
#   PFE-XOM         0.02%
#
# Pairs Trading Temporal Validation (TV2) Summary:
#      Pair Annual Return
# AAPL-MSFT         1.61%
#  AAPL-JPM         2.75%
#  AAPL-PFE        -1.15%
#  AAPL-XOM         8.38%
#  MSFT-JPM         6.23%
#  MSFT-PFE        -1.86%
#  MSFT-XOM         8.28%
#   JPM-PFE        -5.20%
#   JPM-XOM        -4.35%
#   PFE-XOM         1.29%
#
# Pairs Trading Temporal Validation (TV3) Summary:
#      Pair Annual Return
# AAPL-MSFT        -5.89%
#  AAPL-JPM         7.17%
#  AAPL-PFE         3.48%
#  AAPL-XOM         5.62%
#  MSFT-JPM         8.51%
#  MSFT-PFE         1.55%
#  MSFT-XOM         1.18%
#   JPM-PFE         0.76%
#   JPM-XOM        -1.27%
#   PFE-XOM         3.87%
#
# Pairs Trading Temporal Validation (TV4) Summary:
#      Pair Annual Return
# AAPL-MSFT        -4.08%
#  AAPL-JPM         6.71%
#  AAPL-PFE        14.34%
#  AAPL-XOM         6.39%
#  MSFT-JPM         3.68%
#  MSFT-PFE        10.48%
#  MSFT-XOM         6.28%
#   JPM-PFE         5.33%
#   JPM-XOM        -1.28%
#   PFE-XOM         6.32%
#
# Pairs Trading Temporal Validation (TV5) Summary:
#      Pair Annual Return
# AAPL-MSFT        -0.81%
#  AAPL-JPM         1.15%
#  AAPL-PFE         6.55%
#  AAPL-XOM         8.07%
#  MSFT-JPM        -5.97%
#  MSFT-PFE         1.32%
#  MSFT-XOM         3.27%
#   JPM-PFE         4.37%
#   JPM-XOM        -0.46%
#   PFE-XOM         2.19%
#
# Pairs Trading Temporal Validation (TV6) Summary:
#      Pair Annual Return
# AAPL-MSFT        -5.70%
#  AAPL-JPM        -3.48%
#  AAPL-PFE         0.08%
#  AAPL-XOM         7.19%
#  MSFT-JPM         0.46%
#  MSFT-PFE         3.58%
#  MSFT-XOM         5.32%
#   JPM-PFE         6.25%
#   JPM-XOM        -0.57%
#   PFE-XOM        13.28%
#
# Pairs Trading Temporal Validation (TV7) Summary:
#      Pair Annual Return
# AAPL-MSFT        -5.68%
#  AAPL-JPM        -6.65%
#  AAPL-PFE         5.04%
#  AAPL-XOM         0.81%
#  MSFT-JPM        -0.50%
#  MSFT-PFE         4.07%
#  MSFT-XOM        -2.10%
#   JPM-PFE        10.33%
#   JPM-XOM       -13.17%
#   PFE-XOM        11.97%
#
# Pairs Trading Temporal Validation (TV8) Summary:
#      Pair Annual Return
# AAPL-MSFT        -6.32%
#  AAPL-JPM         1.44%
#  AAPL-PFE        12.55%
#  AAPL-XOM       -14.13%
#  MSFT-JPM         3.52%
#  MSFT-PFE        13.54%
#  MSFT-XOM       -13.96%
#   JPM-PFE        20.15%
#   JPM-XOM       -12.45%
#   PFE-XOM         8.13%
#
# Pairs Trading Temporal Validation (TV9) Summary:
#      Pair Annual Return
# AAPL-MSFT       -12.93%
#  AAPL-JPM        -8.59%
#  AAPL-PFE        16.74%
#  AAPL-XOM        -2.96%
#  MSFT-JPM         6.02%
#  MSFT-PFE        -0.68%
#  MSFT-XOM        -1.99%
#   JPM-PFE        19.77%
#   JPM-XOM         0.00%
#   PFE-XOM        -0.64%
